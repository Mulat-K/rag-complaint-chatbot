# %% [markdown]
# # Cell 3: Imports

# %%
import sys
import os

# %% [markdown]
# # Add src to path

# %%
# install missing package
# %pip install langchain

from langchain_core.prompts import PromptTemplate

sys.path.append(os.path.abspath('../src'))
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## os.environ["HUGGINGFACEHUB_API_TOKEN"] = "your_token_here"

# %%
try:
    qa_chain = build_rag_chain()
    
    test_questions = [
        "What are the main issues with Credit Cards?",
        "Why are customers complaining about Money Transfers?",
        "Are there hidden fees in the savings accounts?"
    ]
    
    print("--- Starting Qualitative Evaluation ---")
    
    for q in test_questions:
        print(f"\nQuestion: {q}")
        result = qa_chain.invoke({"query": q})
        print(f"Answer: {result['result'].strip()}")
        print("Sources:")
        for doc in result['source_documents'][:2]:
            print(f"- [Product: {doc.metadata['product_category']}] ...{doc.page_content[:100]}...")
            
except Exception as e:
    print(f"Error: {e}")
    print("Ensure you have set the HUGGINGFACEHUB_API_TOKEN")
# Out:
# Error: name 'build_rag_chain' is not defined
# Ensure you have set the HUGGINGFACEHUB_API_TOKEN
